# %% [markdown]
# #1 Install Weights&Biases

# %%
# !pip install wandb   # wandb 설치
# Out:
# ...
#      |████████████████████████████████| 1.7 MB 3.3 MB/s
# ...
#      |████████████████████████████████| 180 kB 53.4 MB/s
# ...
#      |████████████████████████████████| 140 kB 47.6 MB/s
# ...
#      |████████████████████████████████| 97 kB 6.1 MB/s
# ...
#      |████████████████████████████████| 63 kB 1.5 MB/s
# ...
#   Created wheel for subprocess32: filename=subprocess32-3.5.4-py3-none-any.whl size=6502 sha256=2de096ecfd69d98d29c08e12b930d0abfb8a74ed8390e6b62b42ae4ed5789dd3
#   Stored in directory: /root/.cache/pip/wheels/50/ca/fa/8fca8d246e64f19488d07567547ddec8eb084e8c0d7a59226a
# ...
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8807 sha256=ab4529a0014366d87ba88cbc00004ef0e310dffc4cb1e712674485422bb8a67f
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
# Successfully built subprocess32 pathtools
# ...

# %%
# !wandb login    # 사용하기전에 api 키를 넣어주어야 한다.
# Out:
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %% [markdown]
# #2. Quick Start Tutorial with Pytorch
#
# wandb 사이트의 파이토치 퀵 스타트 입니다.
#
# copy : https://wandb.ai/quickstart/pytorch

# %% [markdown]
# wandb 사용 시 가장 먼저 해야 하는 작업입니다.

# %%
import wandb

wandb.init(project="my-test-project", entity="sb2539", name = "first tutorial" )  # project = 프로젝트 이름/ entity = wandb 계정 이름/ name = 저장하기 위해 지어주는 이름
# Out:
# wandb: Currently logged in as: sb2539 (use `wandb login --relogin` to force relogin)
#                     Syncing run <strong><a href="https://wandb.ai/sb2539/my-test-project/runs/3guzg20p" target="_blank">first tutorial</a></strong> to <a href="https://wandb.ai/sb2539/my-test-project" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src="https://wandb.ai/sb2539/my-test-project/runs/3guzg20p?jupyter=true" style="border:none;width:100%;height:420px;display:none;"></iframe>

# %% [markdown]
# ![프토젝트 생성.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# my-test-project가 생성되었고 클릭하면 다음과 같은 결과를 볼 수 있습니다.

# %% [markdown]
# ![프로젝트 누른 후.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# #3. hyperparameter

# %%
wandb.config = {          # 이 예시 처럼 하이퍼 파라미터를 정의할 수 있습니다.
  "learning_rate": 0.001,
  "epochs": 100,
  "batch_size": 128
}

# %%
wandb.log({"loss": loss})

# Optional
wandb.watch(model)
